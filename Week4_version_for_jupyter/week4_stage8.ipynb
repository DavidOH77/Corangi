# %% [markdown]
# <h1>'함께실습$1'  <h1>기본적인 그래프 그려보기

# %%
# 주피터 노트북안에 차트가 그려지도록 하기

# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3], [90, 100, 50])
plt.show()

# %% [markdown]
# <h1>'함께실습$2'  <h1>데이터, 축 이름, 범례 추가

# %%
plt.plot(['Math', 'Korean', 'English'], [90, 100, 50])
plt.xlabel('Subjects')
plt.ylabel('Score')
plt.title('Midterm')

plt.plot(['Math', 'Korean', 'English'], [70, 60, 90])
plt.legend(['OH', 'KIM'])

plt.show()

# %% [markdown]
# <h1>'함께실습$3'  <h1>막대 차트 그리기

# %%
# 막대 차트 그리기
x = ['Math', 'Korean', 'English']
y = [90, 100, 50]

plt.xlabel('Subjects')
plt.ylabel('Score')

plt.bar(x, y, width = 0.7, color = 'pink')
plt.show()

# %% [markdown]
# <h1>'함께실습$4'  <h1>차트 스타일 변경하기

# %%
plt.plot([1,2,3], [90, 100, 50], marker='', markersize = 10, linestyle = ':')
# marker: o, v, ^, s, +, . , 빈문자
# linestyle : -, --, -., :, 빈문자

plt.grid(True) # 격자 그리기
plt.axis([0, 5, 50, 150]) # [x축 최소, x축 최대, y축 최소, y축 최대]

#plt.tight_layout()

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# <h1>'미션$1'  <h1>똑같이 그려보세요

# %%
x1 = [1,2,3]
y1 = [30, 40, 30]

x2 = [7,8,9]
y2 = [30,40,30]

x3_1 = [2]
y3_1 = [30]

x3_2 = [8]
y3_2 = [30]

x4 = [4,5,6]
y4 = [20, 10, 20]

plt.plot(x1, y1, color = 'gray')
plt.plot(x2, y2, color = 'gray')
plt.plot(x3_1, y3_1, color = 'black', markersize = 30, marker = 'o')
plt.plot(x3_2, y3_2, color = 'black', markersize = 30, marker = 'o')
plt.plot(x4, y4, color = 'red')


plt.show()

# %% [markdown]
# <h1>'함께실습$5'  <h1>판다스로 데이터(csv) 불러온 후 seaborn 세팅하기

# %%
# 판다스로 데이터 불러오기

import pandas as pd
train = pd.read_csv('data/train.csv')

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# seaborn 불러오기

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# <h1>'함께실습$6'  <h1>기본적인 산포도 그려보기

# %%
sns.relplot(data=train, x = 'Age', y = 'Survived')

# %% [markdown]
# <h1>'함께실습$7'  <h1>범주 데이터 넣기 & 사이즈 조절

# %%
sns.relplot(data=train, x ='Age', y ='Survived', hue = 'Sex', aspect = 2)

# %% [markdown]
# <h1>'함께실습$8'  <h1>Categorical Scatter Plot 그려보기

# %%
#Categorical Scatter Plot

sns.catplot(data=train, x = 'Pclass', y= 'Fare', aspect =4)

sns.catplot(data=train, x = 'Pclass', y= 'Fare', jitter = False, aspect =4)

sns.catplot(data=train, x = 'Pclass', y= 'Fare', aspect =4, hue='Sex')

# %% [markdown]
# <h1>'함께실습$9'  <h1>Pair plot 기능 사용하기

# %%
sns.pairplot(data = train, hue = 'Sex',
             x_vars = ['Pclass', 'Age', 'Fare'],
             y_vars = ['Survived', 'Age', 'Fare'], height = 3
            
            )

# %% [markdown]
# <h1>'함께실습$10'  <h1>Box plot 그리기

# %%
sns.catplot(data = train, x = 'Pclass', y = 'Fare', kind = 'box')
sns.catplot(data = train, x = 'Pclass', y = 'Fare', kind = 'box', hue= 'Sex')
