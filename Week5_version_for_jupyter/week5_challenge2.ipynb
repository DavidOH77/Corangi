# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
sns.set()

# %%
sns.catplot(data = df, x = 'Pclass' ,y = 'Age', hue = 'Sex', kind = 'box', aspect = 4)
